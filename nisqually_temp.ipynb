# %% [markdown]
# ### To attach temperature data to nisqually data files

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sys import platform

# %%
if platform == "linux" or platform == "linux2":
    data_string = "/home/maria/Documents/data/pied_piper/nisqually/"
    output_String = "/home/maria/Documents/output/pied_piper/nisqually/"
else:
    data_string = "C:/Users/maria/OneDrive/Documents/data/pied_piper/"
    output_string = "C:/Users/maria/OneDrive/Documents/output/pied_piper/"

# %%
year = "2012"
df = pd.read_csv(data_string + year + "_nisqually_all_R_new.csv")
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-37-aa2c7ddb388e> in <module>
#       1 year = "2012"
# ----> 2 df = pd.read_csv(data_string + year + "_nisqually_all_R_new.csv")
#       3 with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
#       4     display(df)
#
# ...

# %%
df = pd.read_excel(data_string + "2014 Nisqually temp logger.xlsx", header=[1])
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(df)
# Out:
#          # Date Time, GMT-08:00  \
# 0        1  2014-01-21 08:00:00
# 1        2  2014-01-21 09:00:00
# 2        3  2014-01-21 10:00:00
# 3        4  2014-01-21 11:00:00
# 4        5  2014-01-21 12:00:00
# 5        6  2014-01-21 13:00:00
# 6        7  2014-01-21 14:00:00
# 7        8  2014-01-21 15:00:00
# 8        9  2014-01-21 16:00:00
# 9       10  2014-01-21 17:00:00
# 10      11  2014-01-21 18:00:00
# 11      12  2014-01-21 19:00:00
# 12      13  2014-01-21 20:00:00
# 13      14  2014-01-21 21:00:00
# 14      15  2014-01-21 22:00:00
# 15      16  2014-01-21 23:00:00
# 16      17  2014-01-22 00:00:00
# 17      18  2014-01-22 01:00:00
# 18      19  2014-01-22 02:00:00
# 19      20  2014-01-22 03:00:00
# 20      21  2014-01-22 04:00:00
# 21      22  2014-01-22 05:00:00
# 22      23  2014-01-22 06:00:00
# 23      24  2014-01-22 07:00:00
# 24      25  2014-01-22 08:00:00
# 25      26  2014-01-22 09:00:00
# 26      27  2014-01-22 10:00:00
# 27      28  2014-01-22 11:00:00
# ...

# %%
df.columns
# Out:
# Index(['#', 'Date Time, GMT-08:00',
#        'Temp, °F (LGR S/N: 9678966, SEN S/N: 9678966)',
#        'Stopped (LGR S/N: 9678966)', 'End Of File (LGR S/N: 9678966)'],
#       dtype='object')

# %%
df = df.rename(columns={'Date Time, GMT-08:00': "datetime",
                        'Temp, °F (LGR S/N: 9678966, SEN S/N: 9678966)': "temp_f"})

# %%
plt.plot(df['datetime'],df['temp_f']) #this doesnt look right

# %%
df = df[(df['Datetime'] > '2012-01-16') & (df['Datetime'] < '2012-08-14')]
plt.plot(df['Datetime'],df['temp_f'])

# %%
df = pd.read_csv(data_string + "Nisqually_temp_2016-2018_15min.csv")
df
# Out:
#           DateTime_UTC  Depth_m  Temp_C  SpCond_uS/cm  Salinity_PSU
# 0      2/11/2016 23:15     2.20     7.1          63.0           0.0
# 1      2/11/2016 23:30     2.21     7.1          63.0           0.0
# 2      2/11/2016 23:45     2.21     7.1          63.0           0.0
# 3       2/12/2016 0:00     2.22     7.1          63.0           0.0
# 4       2/12/2016 0:15     2.24     7.1          63.0           0.0
# ...                ...      ...     ...           ...           ...
# 67786  3/19/2018 19:00     2.29     6.1           NaN           NaN
# 67787  3/19/2018 19:15     2.28     6.2           NaN           NaN
# 67788  3/19/2018 19:30     2.28     6.3           NaN           NaN
# 67789  3/19/2018 19:45     2.27     6.4           NaN           NaN
# 67790  3/19/2018 20:00     2.27     6.5           NaN           NaN
#
# [67791 rows x 5 columns]

# %%
plt.plot(df['Temp_C'])
