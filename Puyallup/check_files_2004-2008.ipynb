# %% [markdown]
# Goal - check all the save data files from 2004-2008 to make sure the column names are consistent

# %%
#imports

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sys import platform
import io
import datetime

if platform == "linux" or platform == "linux2":
    data_string = "/home/maria/Documents/data/pied_piper/puyallup/"
    output_string = "/home/maria/Documents/output/pied_piper/puyallup/"

elif platform == "win32"or platform == "win64":
    data_string = "C:/Users/maria/OneDrive/Documents/data/pied_piper/puyallup/"
    output_string = "C:/Users/maria/OneDrive/Documents/output/pied_piper/puyallup/"

# %%
df_2004 = pd.read_csv(data_string + "2004_puyallup.csv")

with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(df_2004)
# Out:
#      Unnamed: 0        Date    flow  secchi_depth  In_day  In_night     In  \
# 0             0  2004-02-29  1050.0        150.00    8.50     13.75  22.25
# 1             1  2004-03-01   982.0        150.00   10.75     15.25  26.00
# 2             2  2004-03-02   923.0        150.00   10.25     13.75  24.00
# 3             3  2004-03-03   955.0        150.00   10.25     14.25  24.50
# 4             4  2004-03-04  1300.0        150.00    9.25     15.00  24.25
# 5             5  2004-03-05  1360.0        150.00    8.75     14.00  22.75
# 6             6  2004-03-06  1340.0        150.00   10.75     14.75  25.50
# 7             7  2004-03-07  1230.0        150.00    7.50     16.25  23.75
# 8             8  2004-03-08  1370.0        150.00    7.75     14.25  22.00
# 9             9  2004-03-09  1630.0        150.00   10.75     15.75  26.50
# 10           10  2004-03-10  1719.0        150.00    9.50     12.25  21.75
# ...

# %%
#make flow_day, secchi_septh_day and same for night

df_2004['flow_day'] = df_2004['flow']
df_2004['flow_night'] = df_2004['flow']

df_2004['secchi_depth_day'] = df_2004['secchi_depth']
df_2004['secchi_depth_night'] = df_2004['secchi_depth']

df_2004.head()

df_2004.to_csv(data_string + "2004_puyallup.csv")

# %%
df_2005 = pd.read_csv(data_string + "2005_puyallup.csv")

with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(df_2005)
# Out:
#      Unnamed: 0        Date  flow  secchi_depth  In_day  In_night     In  \
# 0             0  2005-02-26   726        135.00    6.50     14.25  20.75
# 1             1  2005-02-27   719        134.00     NaN       NaN  22.75
# 2             2  2005-02-28   733        135.00    8.75     15.75  24.50
# 3             3  2005-03-01   756        135.00     NaN       NaN  23.00
# 4             4  2005-03-02   746        139.00     NaN       NaN  23.75
# 5             5  2005-03-03   744        137.00     NaN       NaN  23.75
# 6             6  2005-03-04   725        138.00     NaN       NaN  24.50
# 7             7  2005-03-05   711        138.00     NaN       NaN  23.75
# 8             8  2005-03-06   700        134.00     NaN       NaN  23.00
# 9             9  2005-03-07   699        138.00     NaN       NaN  24.00
# 10           10  2005-03-08   709        136.00     NaN       NaN  23.25
# 11           11  2005-03-09   704        137.00     NaN       NaN  23.50
# ...

# %%
#make trap efficiency and separate covariates for day and night
#make flow_day, secchi_septh_day and same for night

df_2005['flow_day'] = df_2005['flow']
df_2005['flow_night'] = df_2005['flow']

df_2005['secchi_depth_day'] = df_2005['secchi_depth']
df_2005['secchi_depth_night'] = df_2005['secchi_depth']

df_2005['trap_efficiency'] = df_2005['chinook0_wild_perhour_day']/df_2005['chinook0_wild_perhour_day_estimate']

with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(df_2005)
# Out:
#      Unnamed: 0        Date  flow  secchi_depth  In_day  In_night     In  \
# 0             0  2005-02-26   726        135.00    6.50     14.25  20.75
# 1             1  2005-02-27   719        134.00     NaN       NaN  22.75
# 2             2  2005-02-28   733        135.00    8.75     15.75  24.50
# 3             3  2005-03-01   756        135.00     NaN       NaN  23.00
# 4             4  2005-03-02   746        139.00     NaN       NaN  23.75
# 5             5  2005-03-03   744        137.00     NaN       NaN  23.75
# 6             6  2005-03-04   725        138.00     NaN       NaN  24.50
# 7             7  2005-03-05   711        138.00     NaN       NaN  23.75
# 8             8  2005-03-06   700        134.00     NaN       NaN  23.00
# 9             9  2005-03-07   699        138.00     NaN       NaN  24.00
# 10           10  2005-03-08   709        136.00     NaN       NaN  23.25
# 11           11  2005-03-09   704        137.00     NaN       NaN  23.50
# ...

# %%
df_2005.to_csv(data_string + "2005_puyallup.csv")

# %%
df_2006 = pd.read_csv(data_string + "2006_puyallup.csv")

with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(df_2006)
# Out:
#      Unnamed: 0        Date       flow  secchi_depth  In_day  In_night     In  \
# 0             0  2006-02-24  1590.0000           NaN     NaN     15.00  15.00
# 1             1  2006-02-25  1370.0000         109.0     NaN       NaN  12.00
# 2             2  2006-02-26  1330.0000         101.0    8.50     14.50  23.00
# 3             3  2006-02-27  1640.0000         115.0   10.00     13.25  23.25
# 4             4  2006-02-28  2220.0000          91.0    8.75     12.50  21.25
# 5             5  2006-03-01  2000.0000         168.0    9.00     13.75  22.75
# 6             6  2006-03-02  1830.0000         195.0    9.00     14.75  23.75
# 7             7  2006-03-03  1650.0000         210.0     NaN       NaN  22.75
# 8             8  2006-03-04  1550.0000         113.0     NaN       NaN  24.00
# 9             9  2006-03-05  1470.0000         215.0     NaN       NaN  22.50
# 10           10  2006-03-06  1410.0000         204.0   10.25     13.50  23.75
# ...

# %%
#need to make new column for trap efficiency and for flow_day and flow_night. However, secchi_depth night has been
#recorded in the data sheet. So I need to edit the original jupyter notebook

#done

# %%
df_2007 = pd.read_csv(data_string + "2007_puyallup.csv")

with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(df_2007)
# Out:
#      Unnamed: 0        Date          flow  secchi_depth  In_day  In_night  \
# 0             0  2007-02-24   2015.833333         270.0    7.00     15.50
# 1             1  2007-02-25   1927.916667         275.0     NaN       NaN
# 2             2  2007-02-26   1746.875000         280.0     NaN       NaN
# 3             3  2007-02-27   1570.208333         240.0    7.75     16.00
# 4             4  2007-02-28   1544.375000         240.0    6.50     17.25
# 5             5  2007-03-01   1407.083333         240.0     NaN       NaN
# 6             6  2007-03-02   1310.729167         240.0     NaN       NaN
# 7             7  2007-03-03   2186.562500         200.0    8.00     15.50
# 8             8  2007-03-04   2411.666667         200.0    8.00     16.00
# 9             9  2007-03-05   2424.270833         190.0    8.25     14.25
# 10           10  2007-03-06   2413.645833         200.0   10.00     14.00
# 11           11  2007-03-07   2499.062500         200.0   10.25     13.00
# ...

# %%
# I don't see secchi_depth_night here. also some of the estimate columns are names wrong.
#Need to edit the origin jupyter notebook

#done

#need to 2008

df_2008 = pd.read_csv(data_string + "2008_puyallup.csv")

with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(df_2008)
# Out:
#      Unnamed: 0        Date  flow  secchi_depth  secchi_depth_night  In_day  \
# 0             0  2008-01-18  1280           185                 182    5.25
# 1             1  2008-01-19  1200           185                 190   10.75
# 2             2  2008-01-20  1190           190                 190   10.75
# 3             3  2008-01-21  1030           190                 192    9.00
# 4             4  2008-01-22   910           194                 197    9.50
# 5             5  2008-01-23   867           194                 196    9.50
# 6             6  2008-01-24   831           200                 198    8.75
# 7             7  2008-01-25   770           198                 192    8.75
# 8             8  2008-01-26   759           193                 205    7.25
# 9             9  2008-01-27   842           192                 195    8.50
# 10           10  2008-01-28   777           196                 190    8.25
# ...

# %%
# need to add flow day and flow night , and secchi depth day

# I also need to rename night_num to num_nigh and day_num to num_day

df_2008['flow_day'] = df_2008['flow']
df_2008['flow_night'] = df_2008['flow']

df_2008['secchi_depth_day'] = df_2008['secchi_depth']

df_2008.rename(columns = {
    'chinook0_wild_day_num_estimate':'chinook0_wild_num_day_estimate',
    'chinook0_wild_night_num_estimate':'chinook0_wild_num_night_estimate',
    'chinook0_hatchery_day_num_estimate':'chinook0_hatchery_num_day_estimate',
    'chinook0_hatchery_night_num_estimate':'chinook0_hatchery_num_night_estimate',
    
}, inplace = True)
df_2008.head()
# Out:
#    Unnamed: 0        Date  flow  secchi_depth  secchi_depth_night  In_day  \
# 0           0  2008-01-18  1280           185                 182    5.25
# 1           1  2008-01-19  1200           185                 190   10.75
# 2           2  2008-01-20  1190           190                 190   10.75
# 3           3  2008-01-21  1030           190                 192    9.00
# 4           4  2008-01-22   910           194                 197    9.50
#
#    In_night  In  chinook0_wild_num_day  chinook0_wild_perhour_day  ...  \
# 0     12.75 NaN                    0.0                        NaN  ...
# 1     12.75 NaN                    0.0                        NaN  ...
# 2     12.50 NaN                    0.0                        NaN  ...
# 3     14.25 NaN                    0.0                        NaN  ...
# 4     13.75 NaN                    0.0                        NaN  ...
#
#    chinook0_hatchery_perhour_day_estimate  \
# 0                                     NaN
# ...

# %%
df_2008.to_csv(data_string + "2008_puyallup.csv")
